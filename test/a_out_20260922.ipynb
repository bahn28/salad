# %% [markdown]
# ## Fetch and Display NYSE Stock Data

# %% [markdown]
# ### yfinance module
# nyse 종목

# %%
# _tsa_00.py
# nyse stock

# 코랩 추가.
# !pip install yfinance

import os
import numpy as np                          # numpy 라이브러리 전체.
import pandas as pd                         # pandas 라이브러리 전체, 시계열(기본) 여기 있네.
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import yfinance as yf                       ## NYSE 데이터 모듈
from scipy import stats, optimize, linalg   # scipy 라이브러리 하부 모듈.
from statsmodels.tsa import stattools       # time series analysis
from statsmodels.tsa.arima.model import ARIMA # 이거 가능하다 이거지. 이거 대문자네. 꼭.
from statsmodels.tsa.ar_model import AutoReg
# Out:
# Requirement already satisfied: yfinance in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (0.16.3)
# Requirement already satisfied: lxml>=4.9.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (6.1.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: numpy>=1.16.5 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: pandas>=1.3.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: peewee>=3.16.2 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (4.11.12)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (7.36.2)
# Requirement already satisfied: pytz>=2022.5 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (2026.3.post1)
# Requirement already satisfied: requests>=2.31 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: websockets>=13.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from yfinance) (16.1.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2026.4)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.20)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.8.0)

# %% [markdown]
# ### Tickers and close prices

# %%
# import pandas as pd
# import yfinance as yf

# 종목 리스트 한 번에 가져오는 아이디어.
# 1. 나스닥 주요 상위 종목 티커 리스트
tickers = ["AAPL", "MSFT", "NVDA", "AMZN", "META",
           "GOOGL", "TSLA", "AVGO", "COST", "NFLX",
           "SKHY", "MU", "AMD", "ASML", "TSM",
           "INTC"]
stock_data = []

# 2. 각 종목의 세부 정보 가져오기
for tckr in tickers:
    stock = yf.Ticker(tckr)
    info = stock.info

    stock_data.append({
        "티커": tckr,
        "기업명": info.get("longName", "N/A"),
        "섹터": info.get("sector", "N/A"),
        "현재가($)": info.get("currentPrice", "N/A"),
        "시가총액($)": f"{info.get('marketCap', 0):,}"
    })

# 3. 데이터프레임 변환 및 출력
df_tckr = pd.DataFrame(stock_data)
print(df_tckr)

# 티커에 대한 가격, 볼륨 데이터, k 년 자료 가져오기
df_dat = yf.download(tickers, period='1y', auto_adjust=True)
df_dat.info()   # ticker마다 close, open, volume 등

# 다운 자료 중 종가 추출
df_dat_cls = df_dat['Close'].copy()
df_dat_cls
# Out:
#        티커                                                기업명  \
# 0    AAPL                                         Apple Inc.
# 1    MSFT                              Microsoft Corporation
# 2    NVDA                                 NVIDIA Corporation
# 3    AMZN                                   Amazon.com, Inc.
# 4    META                               Meta Platforms, Inc.
# 5   GOOGL                                      Alphabet Inc.
# 6    TSLA                                        Tesla, Inc.
# 7    AVGO                                      Broadcom Inc.
# 8    COST                       Costco Wholesale Corporation
# 9    NFLX                                      Netflix, Inc.
# 10   SKHY                                      SK hynix Inc.
# 11     MU                            Micron Technology, Inc.
# 12    AMD                       Advanced Micro Devices, Inc.
# 13   ASML                                  ASML Holding N.V.
# 14    TSM  Taiwan Semiconductor Manufacturing Company Lim...
# 15   INTC                                  Intel Corporation
#
#                         섹터    현재가($)            시가총액($)
# 0               Technology   338.980  4,947,135,430,656
# 1               Technology   501.610  3,724,727,812,096
# 2               Technology   227.380  5,490,544,738,304
# 3        Consumer Cyclical   258.450  2,787,722,657,792
# 4   Communication Services   741.245  1,888,326,254,592
# 5   Communication Services   354.970  4,341,260,091,392
# 6        Consumer Cyclical   375.300  1,482,265,198,592
# 7               Technology   362.660  1,731,204,612,096
# 8       Consumer Defensive   898.480    398,456,848,384
# 9   Communication Services    73.360    305,466,605,568
# 10              Technology   188.860  1,342,937,104,384
# 11              Technology  1043.960  1,179,041,267,712
# 12              Technology   615.520  1,004,821,020,672
# 13              Technology  1711.320    657,318,019,072
# 14              Technology   445.140  2,308,707,188,736
# 15              Technology   121.780    643,741,843,456
# [                       0%                       ]
# [******                12%                       ]  2 of 16 completed
# [*********             19%                       ]  3 of 16 completed
# [************          25%                       ]  4 of 16 completed
# [***************       31%                       ]  5 of 16 completed
# [******************    38%                       ]  6 of 16 completed
# [********************* 44%                       ]  7 of 16 completed
# [**********************50%                       ]  8 of 16 completed
# [**********************56%**                     ]  9 of 16 completed
# [**********************62%*****                  ]  10 of 16 completed
# [**********************69%********               ]  11 of 16 completed
# [**********************75%***********            ]  12 of 16 completed
# [**********************81%**************         ]  13 of 16 completed
# [**********************88%*****************      ]  14 of 16 completed
# [**********************94%********************   ]  15 of 16 completed
# [*********************100%***********************]  16 of 16 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2025-09-22 to 2026-09-21
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Close, AAPL)    251 non-null    float64
#  1   (Close, AMD)     251 non-null    float64
#  2   (Close, AMZN)    251 non-null    float64
#  3   (Close, ASML)    251 non-null    float64
#  4   (Close, AVGO)    251 non-null    float64
#  5   (Close, COST)    251 non-null    float64
#  6   (Close, GOOGL)   251 non-null    float64
#  7   (Close, INTC)    251 non-null    float64
#  8   (Close, META)    251 non-null    float64
#  9   (Close, MSFT)    251 non-null    float64
#  10  (Close, MU)      251 non-null    float64
#  11  (Close, NFLX)    251 non-null    float64
#  12  (Close, NVDA)    251 non-null    float64
#  13  (Close, SKHY)    51 non-null     float64
#  14  (Close, TSLA)    251 non-null    float64
#  15  (Close, TSM)     251 non-null    float64
#  16  (High, AAPL)     251 non-null    float64
#  17  (High, AMD)      251 non-null    float64
#  18  (High, AMZN)     251 non-null    float64
#  19  (High, ASML)     251 non-null    float64
#  20  (High, AVGO)     251 non-null    float64
#  21  (High, COST)     251 non-null    float64
#  22  (High, GOOGL)    251 non-null    float64
#  23  (High, INTC)     251 non-null    float64
#  24  (High, META)     251 non-null    float64
#  25  (High, MSFT)     251 non-null    float64
#  26  (High, MU)       251 non-null    float64
#  27  (High, NFLX)     251 non-null    float64
#  28  (High, NVDA)     251 non-null    float64
#  29  (High, SKHY)     51 non-null     float64
#  30  (High, TSLA)     251 non-null    float64
#  31  (High, TSM)      251 non-null    float64
#  32  (Low, AAPL)      251 non-null    float64
#  33  (Low, AMD)       251 non-null    float64
#  34  (Low, AMZN)      251 non-null    float64
#  35  (Low, ASML)      251 non-null    float64
#  36  (Low, AVGO)      251 non-null    float64
#  37  (Low, COST)      251 non-null    float64
#  38  (Low, GOOGL)     251 non-null    float64
#  39  (Low, INTC)      251 non-null    float64
#  40  (Low, META)      251 non-null    float64
#  41  (Low, MSFT)      251 non-null    float64
#  42  (Low, MU)        251 non-null    float64
#  43  (Low, NFLX)      251 non-null    float64
#  44  (Low, NVDA)      251 non-null    float64
#  45  (Low, SKHY)      51 non-null     float64
#  46  (Low, TSLA)      251 non-null    float64
#  47  (Low, TSM)       251 non-null    float64
#  48  (Open, AAPL)     251 non-null    float64
#  49  (Open, AMD)      251 non-null    float64
#  50  (Open, AMZN)     251 non-null    float64
#  51  (Open, ASML)     251 non-null    float64
#  52  (Open, AVGO)     251 non-null    float64
#  53  (Open, COST)     251 non-null    float64
#  54  (Open, GOOGL)    251 non-null    float64
#  55  (Open, INTC)     251 non-null    float64
#  56  (Open, META)     251 non-null    float64
#  57  (Open, MSFT)     251 non-null    float64
#  58  (Open, MU)       251 non-null    float64
#  59  (Open, NFLX)     251 non-null    float64
#  60  (Open, NVDA)     251 non-null    float64
#  61  (Open, SKHY)     51 non-null     float64
#  62  (Open, TSLA)     251 non-null    float64
#  63  (Open, TSM)      251 non-null    float64
#  64  (Volume, AAPL)   251 non-null    int64
#  65  (Volume, AMD)    251 non-null    int64
#  66  (Volume, AMZN)   251 non-null    int64
#  67  (Volume, ASML)   251 non-null    int64
#  68  (Volume, AVGO)   251 non-null    int64
#  69  (Volume, COST)   251 non-null    int64
#  70  (Volume, GOOGL)  251 non-null    int64
#  71  (Volume, INTC)   251 non-null    int64
#  72  (Volume, META)   251 non-null    int64
#  73  (Volume, MSFT)   251 non-null    int64
#  74  (Volume, MU)     251 non-null    int64
#  75  (Volume, NFLX)   251 non-null    int64
#  76  (Volume, NVDA)   251 non-null    int64
#  77  (Volume, SKHY)   51 non-null     float64
#  78  (Volume, TSLA)   251 non-null    int64
#  79  (Volume, TSM)    251 non-null    int64
# dtypes: float64(65), int64(15)
# memory usage: 158.8 KB
# Ticker            AAPL         AMD        AMZN         ASML        AVGO  \
# Date
# 2025-09-22  255.137512  159.789993  227.630005   951.532593  336.289612
# 2025-09-23  253.493607  160.899994  220.710007   957.205261  336.438477
# 2025-09-24  251.381393  160.880005  220.210007   940.743713  336.805756
# 2025-09-25  255.924606  161.270004  218.149994   943.336609  333.619446
# 2025-09-26  254.519806  159.460007  219.779999   945.293701  332.061005
# ...                ...         ...         ...          ...         ...
# 2026-09-15  331.339996  504.200012  248.419998  1591.479980  338.653320
# 2026-09-16  332.410004  512.500000  245.960007  1602.219971  338.892914
# 2026-09-17  337.000000  545.090027  251.190002  1629.670044  346.668732
# 2026-09-18  336.130005  559.820007  253.710007  1679.920044  356.959991
# 2026-09-21  338.980011  615.520020  258.450012  1711.319946  362.660004
#
# Ticker            COST       GOOGL        INTC        META        MSFT  \
# Date
# 2025-09-22  937.788452  251.874954   28.760000  762.573242  510.251862
# 2025-09-23  938.126465  251.007217   29.340000  752.846313  505.074432
# 2025-09-24  939.786743  246.498947   31.219999  758.088440  505.986908
# 2025-09-25  937.838196  245.152420   33.990002  746.378174  502.892365
# 2025-09-26  910.636841  245.900482   35.500000  741.235657  507.286194
# ...                ...         ...         ...         ...         ...
# 2026-09-15  901.349976  344.980011   97.139999  669.711487  497.119995
# 2026-09-16  893.739990  342.869995  101.050003  672.779053  490.299988
# 2026-09-17  893.929993  347.329987  108.800003  681.771973  497.750000
# 2026-09-18  895.309998  349.540009  108.599998  665.225037  493.779999
# 2026-09-21  898.479980  354.970001  121.779999  741.250000  501.609985
#
# Ticker               MU        NFLX        NVDA        SKHY        TSLA  \
# Date
# 2025-09-22   164.356201  122.737000  183.171158         NaN  434.209991
# 2025-09-23   166.143326  121.847000  178.003540         NaN  425.850006
# 2025-09-24   161.450882  120.394997  176.547028         NaN  442.790009
# 2025-09-25   156.578690  120.823997  177.265305         NaN  423.390015
# 2025-09-26   157.017975  121.060997  177.764114         NaN  440.399994
# ...                 ...         ...         ...         ...         ...
# 2026-09-15   927.599976   77.900002  212.169998  174.830002  356.579987
# 2026-09-16   926.549988   76.410004  213.899994  174.869995  358.079987
# 2026-09-17   977.500000   75.309998  219.339996  182.990005  366.200012
# 2026-09-18  1015.799988   71.790001  222.270004  187.500000  364.269989
# 2026-09-21  1043.959961   73.360001  227.380005  188.860001  375.299988
#
# Ticker             TSM
# Date
# 2025-09-22  269.774780
# 2025-09-23  279.749237
# 2025-09-24  277.770142
# 2025-09-25  273.762573
# 2025-09-26  270.497131
# ...                ...
# 2026-09-15  412.643005
# 2026-09-16  417.720001
# 2026-09-17  430.260010
# 2026-09-18  434.670013
# 2026-09-21  445.140015
#
# [251 rows x 16 columns]

# %% [markdown]
# ### subplots, line chart, prices, returns

# %%
# NYSE daily stock prices and trading volumes
# 변수로 받는 방법.
yymmdd = df_dat.index   # 자료를 불러올 때, 자동으로 기준 인덱스로 설정된다고 함.
yymmdd = pd.to_datetime( yymmdd )

n_plot = len(tickers)
sub_c = 3
sub_r = int(np.ceil(n_plot/sub_c))

fig, axes = plt.subplots(sub_r, sub_c,
                         figsize=(sub_c*4, sub_r*2.5),
                         sharex=True,
                         sharey=True
                         )

for ax, ticker in zip(axes.flat, tickers) :
  ax.plot(yymmdd,
          df_dat_cls[ticker].pct_change(fill_method=None),
          color='blue',
          linewidth=0.3
          )  # 여기 ticker는 이미 "AAPL"처럼 인식, 앞에서.
  ax.set_title(f"  Daily stock returns for {ticker} ", fontsize=10)
  ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
  ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### subplots, histograms, daily returns

# %%
# NYSE daily stock prices and trading volumes
# 변수로 받는 방법.
#yymmdd = df_dat.index   # 자료를 불러올 때, 자동으로 기준 인덱스로 설정된다고 함.
#yymmdd = pd.to_datetime( yymmdd )

n_plot = len(tickers)
sub_c = 3
sub_r = int(np.ceil(n_plot/sub_c))

b_class = [-0.2, -0.175, -0.15, -0.125, -0.1, -0.075, -0.05,-0.025, 0.0, 0.03125, 0.0625, 0.095, 0.125, 0.15, 0.1875, 0.2, 0.25]

fig, axes = plt.subplots(sub_r, sub_c,
                         figsize=(sub_c*4, sub_r*2.5),
                         sharex=True,
                         sharey=True
                         )
for ax, ticker in zip(axes.flat, tickers) :
  ax.hist(df_dat_cls[ticker].pct_change(fill_method=None), # 여기 ticker는 이미 "AAPL"처럼 인식, 앞에서.
          color='blue',
          linewidth=0.5,
          bins = b_class,       # 11처럼 갯수로 지정, 혹은 계급 구간 제시,
          facecolor='None',
          edgecolor='blue',
          density=True
          )
  ax.set_title(f" Histogram of daily returns for  {ticker} ", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### two tickers, prices
# 뭔가 간단하게

# %%
# NYSE daily stock prices and trading volumes
# 변수로 받는 방법.
yymmdd = df_dat.index   # 자료를 불러올 때, 자동으로 기준 인덱스로 설정된다고 함.
yymmdd = pd.to_datetime( yymmdd )

tic_1 = 'NFLX'
tic_2 = 'GOOGL'
stck_prc_1= df_dat_cls[tic_1]
stck_prc_2 = df_dat_cls[tic_2]

# %% [markdown]
# #### daily stock returns

# %%
# 나란히 차트 2개. 1행, 2열.
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16*0.75, 10*0.75/2), sharex=True, sharey=True )
axes[0].plot(yymmdd, stck_prc_1.pct_change(fill_method=None), color='blue', linewidth=0.5)
axes[1].plot(yymmdd, stck_prc_2.pct_change(fill_method=None), color='red', linewidth=0.5)

axes[0].set_title(f" Daily stock returns for {tic_1}")
axes[1].set_title(f" Daily stock returns for {tic_2} ")
axes[0].xaxis.set_major_locator(mdates.MonthLocator(interval=2))
axes[0].xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))

# %% [markdown]
# #### distibutions in one chart

# %%
# 차트 여러 개, 화면 1개.
b_class = [-0.15, -0.1, -0.075, -0.05, -0.025, 0, 0.025, 0.05, 0.1, 0.15 ]
plt.figure(figsize=(12, 7.5))
plt.hist(stck_prc_1.pct_change(fill_method=None),
         color='blue',
         linewidth=0.51,
         bins = b_class, # 11,
         facecolor='None',
         edgecolor='black',
         density=True,
         label = f"{tic_1}"
         )
plt.hist(stck_prc_2.pct_change(fill_method=None),
         color='blue',
         linewidth=1,
         bins = b_class, # 11,
         facecolor='blue',
         edgecolor='None',
         density=True,
         #linestyle='--'
         label = f"{tic_2}",
         alpha = 0.3
         )
plt.title(f" Distribution of daily returns for {tic_1} and {tic_2} ")
plt.legend()
plt.show()
